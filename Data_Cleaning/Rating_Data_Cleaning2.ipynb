# %% [markdown]
# <a href="https://colab.research.google.com/github/HussainPythonista/Movie-Product-Recommendation-System/blob/main/Data_Cleaning/Rating_Data_Cleaning2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Testing the python
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ### Loading Dataset

# %%
##Importing Necessary library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading Dataset
Rating_Dataframe=pd.read_csv("/content/drive/MyDrive/Movie-Product-Recommendation /Datasets/IMDB/title.ratings.tsv/data.tsv",sep="\t",on_bad_lines='skip')
Rating_Dataframe.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2011
# 1  tt0000002            5.7       271
# 2  tt0000003            6.5      1931
# 3  tt0000004            5.4       179
# 4  tt0000005            6.2      2702

# %% [markdown]
# ## Understanding Data

# %%
## Basic Information about dataset
Rating_Dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382915 entries, 0 to 1382914
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1382915 non-null  object
#  1   averageRating  1382915 non-null  float64
#  2   numVotes       1382915 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 31.7+ MB

# %% [markdown]
# **It shows There is no null values in dataset**

# %%
## Describe the dataset
Rating_Dataframe.describe(percentiles=[0.80,0.90,0.91,0.92,0.93,0.94,0.95,0.96,0.97,0.98,0.99]).T
# Out:
#                    count         mean           std  min   50%    80%    90%  \
# averageRating  1382915.0     6.957913      1.384398  1.0   7.2    8.1    8.5
# numVotes       1382915.0  1037.166107  17603.297436  5.0  26.0  150.0  476.0
#
#                  91%    92%    93%     94%     95%     96%      97%     98%  \
# averageRating    8.6    8.7    8.7     8.8     8.9     9.0     9.20     9.4
# numVotes       563.0  674.0  826.0  1040.0  1343.0  1818.0  2656.58  4327.0
#
#                     99%        max
# averageRating      9.70       10.0
# numVotes       10833.86  2832685.0

# %%
Rating_Dataframe[(Rating_Dataframe["numVotes"]>100.0)]
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2011
# 1        tt0000002            5.7       271
# 2        tt0000003            6.5      1931
# 3        tt0000004            5.4       179
# 4        tt0000005            6.2      2702
# ...            ...            ...       ...
# 1382877  tt9916200            8.1       238
# 1382878  tt9916204            8.2       275
# 1382882  tt9916270            5.8      1458
# 1382886  tt9916362            6.4      5649
# 1382887  tt9916380            8.2       117
#
# [347410 rows x 3 columns]

# %% [markdown]
# **In this dataset which looks good but for recomentation number of votes is way less so I'm gonna drop some of the rows which row is low**

# %%
#sorting the dataset based on numVotes for better visualization of data

Rating_Dataframe.sort_values("numVotes")
# Out:
#              tconst  averageRating  numVotes
# 691457   tt14583864            8.0         5
# 591458    tt1255827            3.2         5
# 591478    tt1255866            7.8         5
# 1004322  tt29169158            9.8         5
# 591489    tt1255884            5.6         5
# ...             ...            ...       ...
# 438892    tt0944947            9.2   2233916
# 99265     tt0137523            8.8   2268359
# 651750    tt1375666            8.8   2498225
# 252144    tt0468569            9.0   2814020
# 82680     tt0111161            9.3   2832685
#
# [1382915 rows x 3 columns]

# %% [markdown]
# ### Box plot
# - Using the box plot for better visual of data distribution to drop the reviews which less thean specific limit

# %%
plt.boxplot(Rating_Dataframe["numVotes"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78fbbd457c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78fbbd456b60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78fbbd4568f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x78fbbd755e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78fbbd754490>],
#  'means': []}

# %% [markdown]
# #### If I drop the rows based on condition, Might loose lot of information so i keep it as of now
