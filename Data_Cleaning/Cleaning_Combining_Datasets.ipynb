# %% [markdown]
# #Merging different types of Datas
#
#   In this notebook, we are going to merge multiple dataset into single and major dataset for traing puropse, and do some minor cleaning as well, because we should make sure our dataset are clean and neat

# %% [markdown]
# ### Importing and perform necessary statistical operation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importing Amazon dataset
sales=pd.read_csv("/content/drive/MyDrive/Movie-Product-Recommendation /Datasets/Amazon/Amazon Sales/amazon.csv")


electronics_ratings=pd.read_csv("/content/drive/MyDrive/Movie-Product-Recommendation /Datasets/Amazon/amazon_Review_dataset/ratings_Electronics (1).csv",names=["user_id","product_id","rating","timestamp"])

#Importing Walmart dataset
walmart_data=pd.read_csv("/content/drive/MyDrive/Movie-Product-Recommendation /Datasets/Cleaned Data/walmart.csv")
walmart_data.drop(columns="Unnamed: 0",inplace=True)

# %%
electronics_ratings
# Out:
#                 user_id  product_id  rating   timestamp
# 0         AKM1MP6P0OYPR  0132793040     5.0  1365811200
# 1        A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 2        A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 3        A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 4        A1GI0U4ZRJA8WN  0439886341     1.0  1334707200
# ...                 ...         ...     ...         ...
# 7824477  A2YZI3C9MOHC0L  BT008UKTMW     5.0  1396569600
# 7824478  A322MDK0M89RHN  BT008UKTMW     5.0  1313366400
# 7824479  A1MH90R0ADMIK0  BT008UKTMW     4.0  1404172800
# 7824480  A10M2KEFPEQDHN  BT008UKTMW     4.0  1297555200
# 7824481  A2G81TMIOIDEQQ  BT008V9J9U     5.0  1312675200
#
# [7824482 rows x 4 columns]

# %%
electronics_ratings.describe()
# Out:
#              rating     timestamp
# count  7.824482e+06  7.824482e+06
# mean   4.012337e+00  1.338178e+09
# std    1.380910e+00  6.900426e+07
# min    1.000000e+00  9.127296e+08
# 25%    3.000000e+00  1.315354e+09
# 50%    5.000000e+00  1.361059e+09
# 75%    5.000000e+00  1.386115e+09
# max    5.000000e+00  1.406074e+09

# %%
sales.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# Checking with walmart

# %%
walmart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  30000 non-null  object
#  1   List Price    30000 non-null  float64
#  2   Sale Price    30000 non-null  float64
#  3   Brand         29481 non-null  object
#  4   Category      29976 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# **I found There is some NaN values in Walmart dataset**

# %%
walmart_data.isna().sum()
# Out:
# Product Name      0
# List Price        0
# Sale Price        0
# Brand           519
# Category         24
# dtype: int64

# %% [markdown]
# Creating New Dataframe with only NaN values, because if we do  it Main DataFrame we might get confusion so I'go to this method

# %%
null_data=walmart_data[walmart_data["Brand"].isna()==True]
null_data
# Out:
#                                             Product Name  List Price  \
# 79     Lifesavers Mints Wint O Green 3-72 oz. upc 022...       31.76
# 144                       Hex Nut | Golf Cart ( 20 Pack)        9.99
# 283    6PCS Kids Beach Toys Set Molds Tools Sandbox T...       16.77
# 287    25.4*520mm Cycling Bicycle Handlebar MTB Mount...        8.25
# 461    EECOO 1Pc Newborn Infant Baby Carrier Backpack...       22.83
# ...                                                  ...         ...
# 29713                                  BREATH OF SCANDAL       16.99
# 29715  Cherry Shape Clean Tool Toilet Bathroom Toilet...       16.27
# 29734  STARS AND STRIPES FLANNEL BACK TABLE COVER,54"...       37.00
# 29735  (2 Pack) Crown Prince 1-Layer Brisling Sardine...        4.64
# 29917             Wonderful Honey VIP for Men 12 Sachets       32.50
#
#        Sale Price Brand                                           Category
# ...

# %%
null_data_get=(null_data["Product Name"].str.split(" ").apply(lambda x:x[:2]))
null_data['Brand']=(null_data_get.apply(lambda x:" ".join(x)))
# Out:
# <ipython-input-19-6a660f862589>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_data['Brand']=(null_data_get.apply(lambda x:" ".join(x)))

# %%
# null_data["Brand"].to_numpy()

# %%
null_data
# Out:
#                                             Product Name  List Price  \
# 79     Lifesavers Mints Wint O Green 3-72 oz. upc 022...       31.76
# 144                       Hex Nut | Golf Cart ( 20 Pack)        9.99
# 283    6PCS Kids Beach Toys Set Molds Tools Sandbox T...       16.77
# 287    25.4*520mm Cycling Bicycle Handlebar MTB Mount...        8.25
# 461    EECOO 1Pc Newborn Infant Baby Carrier Backpack...       22.83
# ...                                                  ...         ...
# 29713                                  BREATH OF SCANDAL       16.99
# 29715  Cherry Shape Clean Tool Toilet Bathroom Toilet...       16.27
# 29734  STARS AND STRIPES FLANNEL BACK TABLE COVER,54"...       37.00
# 29735  (2 Pack) Crown Prince 1-Layer Brisling Sardine...        4.64
# 29917             Wonderful Honey VIP for Men 12 Sachets       32.50
#
#        Sale Price               Brand  \
# 79          31.76    Lifesavers Mints
# 144          9.99             Hex Nut
# ...

# %% [markdown]
# **Filling NaN in Main Dataframe**

# %%
walmart_data[walmart_data["Brand"].isna()==True]["Brand"]=walmart_data[walmart_data["Brand"].isna()==True]["Product Name"].str.split(" ").apply(lambda x:x[:2]).apply(lambda x:" ".join(x))
walmart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  30000 non-null  object
#  1   List Price    30000 non-null  float64
#  2   Sale Price    30000 non-null  float64
#  3   Brand         29481 non-null  object
#  4   Category      29976 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 1.1+ MB
# <ipython-input-22-02f9a8f5aebc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
walmart_data.loc[walmart_data["Brand"].isna(), "Brand"] = walmart_data[walmart_data["Brand"].isna()]["Product Name"].str.split(" ").apply(lambda x: " ".join(x[:2]))

# %%
walmart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  30000 non-null  object
#  1   List Price    30000 non-null  float64
#  2   Sale Price    30000 non-null  float64
#  3   Brand         30000 non-null  object
#  4   Category      29976 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 1.1+ MB

# %%
walmart_data["Category"].isna().sum()
# Out:
# 24

# %%
walmart_data["Category"].value_counts()
# Out:
# Sports & Outdoors | Bikes | Bike Components | All Bike Components                                                 301
# Baby | Baby Clearance | Baby Clearance                                                                            250
# Pets | Dogs | Dog Toys | All Dog Toys                                                                             217
# Sports & Outdoors | Sports | Golf Equipment | Golf Clothing                                                       190
# Personal Care | Bath & Body | Body Lotions & Creams                                                               180
#                                                                                                                  ...
# Health | Acid Reflux | Picot                                                                                        1
# Food | Beverages | Juices | Bai                                                                                     1
# ...

# %%
walmart_data.ffill(inplace=True)

# %%
walmart_data
# Out:
#                                             Product Name  List Price  \
# 0      Allegiance Economy Dual-scale Digital Thermometer       11.11
# 1      Kenneth Cole Reaction Eau De Parfum Spray For ...       23.99
# 2      Kid Tough Fitness Inflatable Free-Standing Pun...       30.76
# 3                                        THE FIRST YEARS        6.99
# 4      4 Pack - MD USA Seamless Toe-Wave-In Mesh Diab...       28.27
# ...                                                  ...         ...
# 29995                    Inside Groin Cup with Supporter        6.95
# 29996            Tone Brothers Dromedary Pimientos, 2 oz       14.82
# 29997  Brittanies Thyme 242091 16 oz Organic Olive Oi...       16.15
# 29998  30-Foot Round Boulder Swirl Unibead Above Grou...      414.99
# 29999                         Realtree Mens Jacket Parka       44.88
#
#        Sale Price                    Brand  \
# 0           11.11          Cardinal Health
# 1           23.99             Kenneth Cole
# ...

# %% [markdown]
# ### Observation
#
# The walmart dataset looks way fine for doing further process, so we I'm moving to another steps of the process of analysis

# %% [markdown]
# #### Perform some basic opertion in Amazon Dataset

# %%
electronics_ratings
# Out:
#                 user_id  product_id  rating   timestamp
# 0         AKM1MP6P0OYPR  0132793040     5.0  1365811200
# 1        A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 2        A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 3        A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 4        A1GI0U4ZRJA8WN  0439886341     1.0  1334707200
# ...                 ...         ...     ...         ...
# 7824477  A2YZI3C9MOHC0L  BT008UKTMW     5.0  1396569600
# 7824478  A322MDK0M89RHN  BT008UKTMW     5.0  1313366400
# 7824479  A1MH90R0ADMIK0  BT008UKTMW     4.0  1404172800
# 7824480  A10M2KEFPEQDHN  BT008UKTMW     4.0  1297555200
# 7824481  A2G81TMIOIDEQQ  BT008V9J9U     5.0  1312675200
#
# [7824482 rows x 4 columns]

# %%
#Droping Unwanted column
electronics_ratings=electronics_ratings.drop(columns="timestamp")

# %%
electronics_ratings
# Out:
#                 user_id  product_id  rating
# 0         AKM1MP6P0OYPR  0132793040     5.0
# 1        A2CX7LUOHB2NDG  0321732944     5.0
# 2        A2NWSAGRHCP8N5  0439886341     1.0
# 3        A2WNBOD3WNDNKT  0439886341     3.0
# 4        A1GI0U4ZRJA8WN  0439886341     1.0
# ...                 ...         ...     ...
# 7824477  A2YZI3C9MOHC0L  BT008UKTMW     5.0
# 7824478  A322MDK0M89RHN  BT008UKTMW     5.0
# 7824479  A1MH90R0ADMIK0  BT008UKTMW     4.0
# 7824480  A10M2KEFPEQDHN  BT008UKTMW     4.0
# 7824481  A2G81TMIOIDEQQ  BT008V9J9U     5.0
#
# [7824482 rows x 3 columns]

# %% [markdown]
# Checking Unique Values for joining dataset with product information

# %%
print(electronics_ratings.product_id.unique())
print(len(electronics_ratings.product_id.unique()))
electronics_ratings
# Out:
# ['0132793040' '0321732944' '0439886341' ... 'BT008T2BGK' 'BT008UKTMW'
#  'BT008V9J9U']
# 476002
#                 user_id  product_id  rating
# 0         AKM1MP6P0OYPR  0132793040     5.0
# 1        A2CX7LUOHB2NDG  0321732944     5.0
# 2        A2NWSAGRHCP8N5  0439886341     1.0
# 3        A2WNBOD3WNDNKT  0439886341     3.0
# 4        A1GI0U4ZRJA8WN  0439886341     1.0
# ...                 ...         ...     ...
# 7824477  A2YZI3C9MOHC0L  BT008UKTMW     5.0
# 7824478  A322MDK0M89RHN  BT008UKTMW     5.0
# 7824479  A1MH90R0ADMIK0  BT008UKTMW     4.0
# 7824480  A10M2KEFPEQDHN  BT008UKTMW     4.0
# 7824481  A2G81TMIOIDEQQ  BT008V9J9U     5.0
#
# [7824482 rows x 3 columns]

# %% [markdown]
# #### Checking Sales Dataset in Amazon Sales

# %%
sales
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
sales["product_id"].drop_duplicates(inplace=True)

# %%
sales_final=sales.drop_duplicates(subset=['product_id'], keep=False,ignore_index=True)

# %%
sales_final
# Out:
#       product_id                                       product_name  \
# 0     B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 1     B0B6F7LX4C  MI 80 cm (32 inches) 5A Series HD Ready Smart ...
# 2     B0B1YVCJ2Y  Acer 80 cm (32 inches) I Series HD Ready Andro...
# 3     B08B42LWKN  OnePlus 80 cm (32 inches) Y Series HD Ready LE...
# 4     B0B3MMYHYW  OnePlus 126 cm (50 inches) Y Series 4K Ultra H...
# ...          ...                                                ...
# 1254  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1255  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1256  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1257  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1258  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|NetworkingDevices|Networ...             ₹499
# ...

# %%
sales_cleaned=sales_final.drop(columns=["review_id","img_link","product_link","user_name","user_id"])

# %%
sales_cleaned
# Out:
#       product_id                                       product_name  \
# 0     B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 1     B0B6F7LX4C  MI 80 cm (32 inches) 5A Series HD Ready Smart ...
# 2     B0B1YVCJ2Y  Acer 80 cm (32 inches) I Series HD Ready Andro...
# 3     B08B42LWKN  OnePlus 80 cm (32 inches) Y Series HD Ready LE...
# 4     B0B3MMYHYW  OnePlus 126 cm (50 inches) Y Series 4K Ultra H...
# ...          ...                                                ...
# 1254  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1255  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1256  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1257  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1258  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|NetworkingDevices|Networ...             ₹499
# ...

# %% [markdown]
# #### Amazon Sales Dataset

# %%
# import pandas as pd

# Function to handle splitting and filling categories
def fill_categories(row):
    split_categories = row.split('|')
    if len(split_categories) < 3:
        return ['No Category'] * 6
    else:
        return [split_categories[0], split_categories[1], split_categories[-2] if len(split_categories) > 2 else None,
                split_categories[-3] if len(split_categories) > 3 else "No Category", split_categories[2], split_categories[-1]]

# %%
# Apply the function to create new columns
sales_cleaned[['masterCategory', 'subCategory', 'additionalCategory1', 'additionalCategory2',
    'articleType', 'productType']] = sales_cleaned['category'].apply(fill_categories).apply(pd.Series)

# %%
sales_cleaned
# Out:
#       product_id                                       product_name  \
# 0     B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 1     B0B6F7LX4C  MI 80 cm (32 inches) 5A Series HD Ready Smart ...
# 2     B0B1YVCJ2Y  Acer 80 cm (32 inches) I Series HD Ready Andro...
# 3     B08B42LWKN  OnePlus 80 cm (32 inches) Y Series HD Ready LE...
# 4     B0B3MMYHYW  OnePlus 126 cm (50 inches) Y Series 4K Ultra H...
# ...          ...                                                ...
# 1254  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1255  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1256  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1257  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1258  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|NetworkingDevices|Networ...             ₹499
# ...

# %%
#Droping unwanted columns in sales dataset

sales_cleaned.drop(columns=["category","about_product"],inplace=True)

# %%
sales_cleaned
# Out:
#       product_id                                       product_name  \
# 0     B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 1     B0B6F7LX4C  MI 80 cm (32 inches) 5A Series HD Ready Smart ...
# 2     B0B1YVCJ2Y  Acer 80 cm (32 inches) I Series HD Ready Andro...
# 3     B08B42LWKN  OnePlus 80 cm (32 inches) Y Series HD Ready LE...
# 4     B0B3MMYHYW  OnePlus 126 cm (50 inches) Y Series 4K Ultra H...
# ...          ...                                                ...
# 1254  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1255  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1256  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1257  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1258  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#      discounted_price actual_price discount_percentage rating rating_count  \
# ...

# %%
sales_cleaned.drop(columns=["discount_percentage"],inplace=True)

# %%
sales_cleaned
# Out:
#       product_id                                       product_name  \
# 0     B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 1     B0B6F7LX4C  MI 80 cm (32 inches) 5A Series HD Ready Smart ...
# 2     B0B1YVCJ2Y  Acer 80 cm (32 inches) I Series HD Ready Andro...
# 3     B08B42LWKN  OnePlus 80 cm (32 inches) Y Series HD Ready LE...
# 4     B0B3MMYHYW  OnePlus 126 cm (50 inches) Y Series 4K Ultra H...
# ...          ...                                                ...
# 1254  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1255  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1256  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1257  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1258  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#      discounted_price actual_price rating rating_count  \
# 0                ₹499         ₹999    4.2     1,79,691
# ...

# %% [markdown]
# ### Handling Walmart Data and Amazon Data

# %%
walmart_data
# Out:
#                                             Product Name  List Price  \
# 0      Allegiance Economy Dual-scale Digital Thermometer       11.11
# 1      Kenneth Cole Reaction Eau De Parfum Spray For ...       23.99
# 2      Kid Tough Fitness Inflatable Free-Standing Pun...       30.76
# 3                                        THE FIRST YEARS        6.99
# 4      4 Pack - MD USA Seamless Toe-Wave-In Mesh Diab...       28.27
# ...                                                  ...         ...
# 29995                    Inside Groin Cup with Supporter        6.95
# 29996            Tone Brothers Dromedary Pimientos, 2 oz       14.82
# 29997  Brittanies Thyme 242091 16 oz Organic Olive Oi...       16.15
# 29998  30-Foot Round Boulder Swirl Unibead Above Grou...      414.99
# 29999                         Realtree Mens Jacket Parka       44.88
#
#        Sale Price                    Brand  \
# 0           11.11          Cardinal Health
# 1           23.99             Kenneth Cole
# ...

# %%
# Apply the function to create new columns
walmart_data[['masterCategory', 'subCategory', 'additionalCategory1', 'additionalCategory2',
    'articleType', 'productType']] = walmart_data['Category'].apply(fill_categories).apply(pd.Series)

# %%
walmart_data.drop(columns=["Category"],inplace=True)

# %%
walmart_data
# Out:
#                                             Product Name  List Price  \
# 0      Allegiance Economy Dual-scale Digital Thermometer       11.11
# 1      Kenneth Cole Reaction Eau De Parfum Spray For ...       23.99
# 2      Kid Tough Fitness Inflatable Free-Standing Pun...       30.76
# 3                                        THE FIRST YEARS        6.99
# 4      4 Pack - MD USA Seamless Toe-Wave-In Mesh Diab...       28.27
# ...                                                  ...         ...
# 29995                    Inside Groin Cup with Supporter        6.95
# 29996            Tone Brothers Dromedary Pimientos, 2 oz       14.82
# 29997  Brittanies Thyme 242091 16 oz Organic Olive Oi...       16.15
# 29998  30-Foot Round Boulder Swirl Unibead Above Grou...      414.99
# 29999                         Realtree Mens Jacket Parka       44.88
#
#        Sale Price                    Brand      masterCategory  \
# 0           11.11          Cardinal Health             Health
# ...

# %%
walmart_data.columns
# Out:
# Index(['Product Name', 'List Price', 'Sale Price', 'Brand', 'masterCategory',
#        'subCategory', 'additionalCategory1', 'additionalCategory2',
#        'articleType', 'productType'],
#       dtype='object')

# %%
sales_cleaned.drop(columns=["review_title","product_id","review_content","rating","rating_count"],inplace=True)

# %% [markdown]
# **Remove Rupees symbol in price**

# %%
sales_cleaned['discounted_price']=sales_cleaned['discounted_price'].apply(lambda x:x[1:]).apply(lambda x:x.split(",")).str.join("")

# %%
sales_cleaned['actual_price']=sales_cleaned['actual_price'].apply(lambda x:x[1:]).apply(lambda x:x.split(",")).str.join("")

# %%
print(sales_cleaned['actual_price'].dtype,sales_cleaned['discounted_price'].dtype)
# Out:
# object object

# %%
sales_cleaned['discounted_price']=sales_cleaned['discounted_price'].astype("float32")

# %%
sales_cleaned.actual_price.value_counts()
# Out:
# 999      95
# 499      52
# 1999     49
# 1499     35
# 599      29
#          ..
# 32000     1
# 47900     1
# 535       1
# 7005      1
# 3690      1
# Name: actual_price, Length: 439, dtype: int64

# %%
sales_cleaned["Brand"]=sales_cleaned["product_name"].str.split(" ").apply(lambda x:x[:1][0])

# %%
sales_cleaned
# Out:
#                                            product_name  discounted_price  \
# 0     TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...             499.0
# 1     MI 80 cm (32 inches) 5A Series HD Ready Smart ...           13999.0
# 2     Acer 80 cm (32 inches) I Series HD Ready Andro...           11499.0
# 3     OnePlus 80 cm (32 inches) Y Series HD Ready LE...           14999.0
# 4     OnePlus 126 cm (50 inches) Y Series 4K Ultra H...           32999.0
# ...                                                 ...               ...
# 1254  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...             379.0
# 1255  Prestige Delight PRWO Electric Rice Cooker (1 ...            2280.0
# 1256  Bajaj Majesty RX10 2000 Watts Heat Convector R...            2219.0
# 1257  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...            1399.0
# 1258  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...            2863.0
#
#      actual_price         masterCategory                 subCategory  \
# ...

# %%
sales_cleaned.columns
# Out:
# Index(['product_name', 'discounted_price', 'actual_price', 'masterCategory',
#        'subCategory', 'additionalCategory1', 'additionalCategory2',
#        'articleType', 'productType', 'Brand'],
#       dtype='object')

# %%
walmart_data.columns
# Out:
# Index(['Product Name', 'List Price', 'Sale Price', 'Brand', 'masterCategory',
#        'subCategory', 'additionalCategory1', 'additionalCategory2',
#        'articleType', 'productType'],
#       dtype='object')

# %% [markdown]
# #### Rename Columns

# %%
walmart_data.rename(columns={"Product Name":"product_name","List Price":"actual_price","Sale Price":"discounted_price"},inplace=True)

# %%
walmart_data
# Out:
#                                             product_name  actual_price  \
# 0      Allegiance Economy Dual-scale Digital Thermometer         11.11
# 1      Kenneth Cole Reaction Eau De Parfum Spray For ...         23.99
# 2      Kid Tough Fitness Inflatable Free-Standing Pun...         30.76
# 3                                        THE FIRST YEARS          6.99
# 4      4 Pack - MD USA Seamless Toe-Wave-In Mesh Diab...         28.27
# ...                                                  ...           ...
# 29995                    Inside Groin Cup with Supporter          6.95
# 29996            Tone Brothers Dromedary Pimientos, 2 oz         14.82
# 29997  Brittanies Thyme 242091 16 oz Organic Olive Oi...         16.15
# 29998  30-Foot Round Boulder Swirl Unibead Above Grou...        414.99
# 29999                         Realtree Mens Jacket Parka         44.88
#
#        discounted_price                    Brand      masterCategory  \
# ...

# %% [markdown]
# ##### Convert dollars into rupees

# %%
walmart_data['actual_price']=walmart_data['actual_price']*82.80

# %%
walmart_data['discounted_price']=walmart_data['discounted_price']*82.80

# %% [markdown]
# #### Merge Both amazon sales and walmart product dataset to make master product dataset

# %% [markdown]
# **Get the unique data from Amazon dataset**

# %%
#Checking the length of unique datas for assigning
len(electronics_ratings["product_id"].unique())
# Out:
# 476002

# %%
unique_dataset=electronics_ratings.drop_duplicates(subset=["product_id"])

# %%
unique_dataset
# Out:
#                 user_id  product_id  rating
# 0         AKM1MP6P0OYPR  0132793040     5.0
# 1        A2CX7LUOHB2NDG  0321732944     5.0
# 2        A2NWSAGRHCP8N5  0439886341     1.0
# 5        A1QGNMC6O1VW39  0511189877     5.0
# 11       A1DA3W4GTFXP6O  0528881469     5.0
# ...                 ...         ...     ...
# 7824463  A1MTPZKAYVSES3  BT008G3W52     5.0
# 7824464   AS7WVL4JGN1FI  BT008SXQ4C     1.0
# 7824465  A3GGII8ILEUI4P  BT008T2BGK     5.0
# 7824466   ATK4Q037EM13F  BT008UKTMW     4.0
# 7824481  A2G81TMIOIDEQQ  BT008V9J9U     5.0
#
# [476002 rows x 3 columns]

# %%
product_master_data=pd.concat([walmart_data, sales_cleaned], ignore_index=True)

# %%
product_master_data
# Out:
#                                             product_name actual_price  \
# 0      Allegiance Economy Dual-scale Digital Thermometer      919.908
# 1      Kenneth Cole Reaction Eau De Parfum Spray For ...     1986.372
# 2      Kid Tough Fitness Inflatable Free-Standing Pun...     2546.928
# 3                                        THE FIRST YEARS      578.772
# 4      4 Pack - MD USA Seamless Toe-Wave-In Mesh Diab...     2340.756
# ...                                                  ...          ...
# 31254  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...          919
# 31255  Prestige Delight PRWO Electric Rice Cooker (1 ...         3045
# 31256  Bajaj Majesty RX10 2000 Watts Heat Convector R...         3080
# 31257  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...         1890
# 31258  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...         3690
#
#        discounted_price            Brand      masterCategory  \
# 0               919.908  Cardinal Health             Health
# ...

# %%
unique_dataset
# Out:
#                 user_id  product_id  rating
# 0         AKM1MP6P0OYPR  0132793040     5.0
# 1        A2CX7LUOHB2NDG  0321732944     5.0
# 2        A2NWSAGRHCP8N5  0439886341     1.0
# 5        A1QGNMC6O1VW39  0511189877     5.0
# 11       A1DA3W4GTFXP6O  0528881469     5.0
# ...                 ...         ...     ...
# 7824463  A1MTPZKAYVSES3  BT008G3W52     5.0
# 7824464   AS7WVL4JGN1FI  BT008SXQ4C     1.0
# 7824465  A3GGII8ILEUI4P  BT008T2BGK     5.0
# 7824466   ATK4Q037EM13F  BT008UKTMW     4.0
# 7824481  A2G81TMIOIDEQQ  BT008V9J9U     5.0
#
# [476002 rows x 3 columns]

# %%
unique_dataset.reset_index(inplace=True)

# %%
unique_dataset.drop(columns="index",inplace=True)
# Out:
# <ipython-input-72-5df2ce23e980>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_dataset.drop(columns="index",inplace=True)

# %%
unique_dataset
# Out:
#                user_id  product_id  rating
# 0        AKM1MP6P0OYPR  0132793040     5.0
# 1       A2CX7LUOHB2NDG  0321732944     5.0
# 2       A2NWSAGRHCP8N5  0439886341     1.0
# 3       A1QGNMC6O1VW39  0511189877     5.0
# 4       A1DA3W4GTFXP6O  0528881469     5.0
# ...                ...         ...     ...
# 475997  A1MTPZKAYVSES3  BT008G3W52     5.0
# 475998   AS7WVL4JGN1FI  BT008SXQ4C     1.0
# 475999  A3GGII8ILEUI4P  BT008T2BGK     5.0
# 476000   ATK4Q037EM13F  BT008UKTMW     4.0
# 476001  A2G81TMIOIDEQQ  BT008V9J9U     5.0
#
# [476002 rows x 3 columns]

# %%
unique_dataset["product_id"]
# Out:
# 0         0132793040
# 1         0321732944
# 2         0439886341
# 3         0511189877
# 4         0528881469
#              ...
# 475997    BT008G3W52
# 475998    BT008SXQ4C
# 475999    BT008T2BGK
# 476000    BT008UKTMW
# 476001    BT008V9J9U
# Name: product_id, Length: 476002, dtype: object

# %%
amazon_product_id=unique_dataset["product_id"][:len(product_master_data)]
amazon_product_id
# Out:
# 0        0132793040
# 1        0321732944
# 2        0439886341
# 3        0511189877
# 4        0528881469
#             ...
# 31254    B0002V8N06
# 31255    B0002V9G6G
# 31256    B0002V9IJG
# 31257    B0002V9IK0
# 31258    B0002V9IKA
# Name: product_id, Length: 31259, dtype: object

# %%
amazon_id=pd.DataFrame(amazon_product_id)
amazon_id
# Out:
#        product_id
# 0      0132793040
# 1      0321732944
# 2      0439886341
# 3      0511189877
# 4      0528881469
# ...           ...
# 31254  B0002V8N06
# 31255  B0002V9G6G
# 31256  B0002V9IJG
# 31257  B0002V9IK0
# 31258  B0002V9IKA
#
# [31259 rows x 1 columns]

# %%
product_master_data=pd.concat([amazon_id, product_master_data],axis=1)
product_master_data
# Out:
#        product_id                                       product_name  \
# 0      0132793040  Allegiance Economy Dual-scale Digital Thermometer
# 1      0321732944  Kenneth Cole Reaction Eau De Parfum Spray For ...
# 2      0439886341  Kid Tough Fitness Inflatable Free-Standing Pun...
# 3      0511189877                                    THE FIRST YEARS
# 4      0528881469  4 Pack - MD USA Seamless Toe-Wave-In Mesh Diab...
# ...           ...                                                ...
# 31254  B0002V8N06  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 31255  B0002V9G6G  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 31256  B0002V9IJG  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 31257  B0002V9IK0  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 31258  B0002V9IKA  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#       actual_price  discounted_price            Brand      masterCategory  \
# ...

# %% [markdown]
# ### Handling Fashion Data

# %%
#Loading Dataset
fashion_data=pd.read_csv("/content/drive/MyDrive/Movie-Product-Recommendation /Datasets/Fashion Dataset/styles.csv",on_bad_lines='skip')
#fashion_data.drop(columns="Unnamed: 0",inplace=True)

# %%
fashion_data
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44419  17036    Men       Footwear       Shoes           Casual Shoes
# 44420   6461    Men       Footwear  Flip Flops             Flip Flops
# 44421  18842    Men        Apparel     Topwear                Tshirts
# 44422  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44423  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %% [markdown]
# **Checking for duplicates values If found drop duplicated values**

# %%
print("Total number of unique duplicate values is ",len(fashion_data)-len(fashion_data['productDisplayName'].unique()))
# Out:
# Total number of unique duplicate values is  13302

# %% [markdown]
# **I found some of the values are Duplicated check those duplicated values and make defsis**

# %%
df2 = fashion_data[fashion_data['productDisplayName'].duplicated() == True]

# %%
df2.sort_values(by="productDisplayName")
# Out:
#           id  gender masterCategory               subCategory  \
# 42521  46261   Women        Apparel                   Topwear
# 26988  46280   Women        Apparel                   Topwear
# 9061   37905  Unisex  Personal Care                 Fragrance
# 36513  27385     Men        Apparel  Loungewear and Nightwear
# 34222  27384     Men        Apparel  Loungewear and Nightwear
# ...      ...     ...            ...                       ...
# 17639  45687     Men  Personal Care                 Fragrance
# 22089  42863   Women    Accessories                      Bags
# 23484  45698   Women  Personal Care                 Fragrance
# 37531  30992     Men  Personal Care                 Fragrance
# 40675  43119     Men  Personal Care                 Fragrance
#
#                  articleType baseColour  season    year   usage  \
# 42521                 Tunics      Multi  Summer  2012.0  Casual
# 26988                 Tunics      Multi  Summer  2012.0  Casual
# ...

# %% [markdown]
# **After checking the duplicate dataframe it is not a good descion to drop rows so I keep as it is**

# %%
product_master_data.columns
# Out:
# Index(['product_id', 'product_name', 'actual_price', 'discounted_price',
#        'Brand', 'masterCategory', 'subCategory', 'additionalCategory1',
#        'additionalCategory2', 'articleType', 'productType'],
#       dtype='object')

# %%
fashion_data.columns
# Out:
# Index(['id', 'gender', 'masterCategory', 'subCategory', 'articleType',
#        'baseColour', 'season', 'year', 'usage', 'productDisplayName'],
#       dtype='object')

# %% [markdown]
# **In My opinion keep both dataset separate is better for further analysis and model building process**

# %%
product_master_data["masterCategory"].unique()
# Out:
# array(['Health ', 'Premium Beauty ', 'Sports & Outdoors ', 'Baby ',
#        'Food ', 'Clothing ', 'Home ', 'Personal Care ', 'No Category',
#        'Toys ', 'Pets ', 'Auto & Tires ', 'Household Essentials ',
#        'Patio & Garden ', 'Beauty ', 'Home Improvement ',
#        'Shop by Brand ', 'Feature ', 'Party & Occasions ', 'Electronics ',
#        'Industrial & Scientific ', 'Books ', 'Walmart for Business ',
#        'Office Supplies ', 'Video Games ', 'Arts Crafts & Sewing ',
#        'Shop by Movie ', 'Seasonal ', 'Household essentials ',
#        'Party & occasions ', 'Auto & tires ', 'Jewelry ',
#        'Patio & garden ', 'Shop by movie ', 'Music ',
#        'Shop by Video Game ', 'Character Shop ', 'Sports & outdoors ',
#        'Personal care ', 'Premium beauty ', 'Shop by brand ',
#        'Home improvement ', 'Industrial & scientific ',
#        'Arts, Crafts & Sewing ', 'Cell Phones ', 'Musical Instruments ',
# ...

# %% [markdown]
# #### Mapping the category with in generes

# %%
# Create a dictionary mapping fashion product categories to movie-inspired genres
fashion_genre_mapping = {
    'Shirts': 'Drama',
    'Jeans': 'Drama',
    'Watches': 'Action & Adventure',
    'Track Pants': 'Sports & Outdoors',
    'Tshirts': 'Comedy',
    'Socks': 'Family & Kids',
    'Casual Shoes': 'Drama',
    'Belts': 'Action & Adventure',
    'Flip Flops': 'Family & Kids',
    'Handbags': 'Action & Adventure',
    'Tops': 'Drama',
    'Bra': 'Romance',
    'Sandals': 'Family & Kids',
    'Shoe Accessories': 'Action & Adventure',
    'Sweatshirts': 'Drama',
    'Deodorant': 'Comedy',
    'Formal Shoes': 'Drama',
    'Bracelet': 'Romance',
    'Lipstick': 'Romance',
    'Flats': 'Romance',
    'Kurtas': 'Drama',
    'Waistcoat': 'Drama',
    'Sports Shoes': 'Sports & Outdoors',
    'Shorts': 'Comedy',
    'Briefs': 'Romance',
    'Sarees': 'Drama',
    'Perfume and Body Mist': 'Romance',
    'Heels': 'Romance',
    'Sunglasses': 'Fantasy & Sci-Fi',
    'Innerwear Vests': 'Romance',
    'Pendant': 'Romance',
    'Nail Polish': 'Comedy',
    'Laptop Bag': 'Action & Adventure',
    'Scarves': 'Drama',
    'Rain Jacket': 'Thriller & Mystery',
    'Dresses': 'Drama',
    'Night suits': 'Drama',
    'Skirts': 'Drama',
    'Wallets': 'Action & Adventure',
    'Blazers': 'Drama',
    'Ring': 'Romance',
    'Kurta Sets': 'Drama',
    'Clutches': 'Action & Adventure',
    'Shrug': 'Drama',
    'Backpacks': 'Action & Adventure',
    'Caps': 'Fantasy & Sci-Fi',
    'Trousers': 'Drama',
    'Earrings': 'Romance',
    'Camisoles': 'Romance',
    'Boxers': 'Comedy',
    'Jewellery Set': 'Romance',
    'Dupatta': 'Drama',
    'Capris': 'Comedy',
    'Lip Gloss': 'Romance',
    'Bath Robe': 'Comedy',
    'Mufflers': 'Drama',
    'Tunics': 'Drama',
    'Jackets': 'Drama',
    'Trunk': 'Action & Adventure',
    'Lounge Pants': 'Drama',
    'Face Wash and Cleanser': 'Thriller & Mystery',
    'Necklace and Chains': 'Romance',
    'Duffel Bag': 'Action & Adventure',
    'Sports Sandals': 'Sports & Outdoors',
    'Foundation and Primer': 'Romance',
    'Sweaters': 'Drama',
    'Free Gifts': 'Fantasy & Sci-Fi',
    'Trolley Bag': 'Action & Adventure',
    'Tracksuits': 'Sports & Outdoors',
    'Swimwear': 'Comedy',
    'Shoe Laces': 'Sports & Outdoors',
    'Fragrance Gift Set': 'Romance',
    'Bangle': 'Romance',
    'Nightdress': 'Drama',
    'Ties': 'Drama',
    'Baby Dolls': 'Comedy',
    'Leggings': 'Comedy',
    'Highlighter and Blush': 'Romance',
    'Travel Accessory': 'Action & Adventure',
    'Kurtis': 'Drama',
    'Mobile Pouch': 'Action & Adventure',
    'Messenger Bag': 'Action & Adventure',
    'Lip Care': 'Romance',
    'Face Moisturisers': 'Romance',
    'Compact': 'Romance',
    'Eye Cream': 'Romance',
    'Accessory Gift Set': 'Romance',
    'Beauty Accessory': 'Romance',
    'Jumpsuit': 'Comedy',
    'Kajal and Eyeliner': 'Comedy',
    'Water Bottle': 'Comedy',
    'Suspenders': 'Comedy',
    'Lip Liner': 'Romance',
    'Robe': 'Comedy',
    'Salwar and Dupatta': 'Drama',
    'Patiala': 'Drama',
    'Stockings': 'Comedy',
    'Eyeshadow': 'Fantasy & Sci-Fi',
    'Headband': 'Fantasy & Sci-Fi',
    'Tights': 'Comedy',
    'Nail Essentials': 'Comedy',
    'Churidar': 'Drama',
    'Lounge Tshirts': 'Comedy',
    'Face Scrub and Exfoliator': 'Thriller & Mystery',
    'Lounge Shorts': 'Comedy',
    'Gloves': 'Thriller & Mystery',
    'Mask and Peel': 'Thriller & Mystery',
    'Wristbands': 'Sports & Outdoors',
    'Tablet Sleeve': 'Action & Adventure',
    'Ties and Cufflinks': 'Drama',
    'Footballs': 'Sports & Outdoors',
    'Stoles': 'Drama',
    'Shapewear': 'Comedy',
    'Nehru Jackets': 'Drama',
    'Salwar': 'Drama',
    'Cufflinks': 'Drama',
    'Jeggings': 'Comedy',
    'Hair Colour': 'Romance',
    'Concealer': 'Romance',
    'Rompers': 'Comedy',
    'Body Lotion': 'Romance',
    'Sunscreen': 'Comedy',
    'Booties': 'Romance',
    'Waist Pouch': 'Action & Adventure',
    'Hair Accessory': 'Romance',
    'Rucksacks': 'Action & Adventure',
    'Basketballs': 'Sports & Outdoors',
    'Lehenga Choli': 'Drama',
    'Clothing Set': 'Drama',
    'Mascara': 'Romance',
    'Toner': 'Romance',
    'Cushion Covers': 'Drama',
    'Key chain': 'Fantasy & Sci-Fi',
    'Makeup Remover': 'Romance',
    'Lip Plumper': 'Romance',
    'Umbrellas': 'Drama',
    'Face Serum and Gel': 'Romance',
    'Hat': 'Fantasy & Sci-Fi',
    'Mens Grooming Kit': 'Comedy',
    'Rain Trousers': 'Thriller & Mystery',
    'Body Wash and Scrub': 'Thriller & Mystery',
    'Suits': 'Drama',
    'Ipad': 'Fantasy & Sci-Fi'
}

# Apply the updated genre mapping to create the 'Genres' column
fashion_data["movie_generes"]=fashion_data["articleType"].map(fashion_genre_mapping)

# %%
fashion_data
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44419  17036    Men       Footwear       Shoes           Casual Shoes
# 44420   6461    Men       Footwear  Flip Flops             Flip Flops
# 44421  18842    Men        Apparel     Topwear                Tshirts
# 44422  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44423  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
product_master_data["masterCategory"].unique()
# Out:
# array(['Health ', 'Premium Beauty ', 'Sports & Outdoors ', 'Baby ',
#        'Food ', 'Clothing ', 'Home ', 'Personal Care ', 'No Category',
#        'Toys ', 'Pets ', 'Auto & Tires ', 'Household Essentials ',
#        'Patio & Garden ', 'Beauty ', 'Home Improvement ',
#        'Shop by Brand ', 'Feature ', 'Party & Occasions ', 'Electronics ',
#        'Industrial & Scientific ', 'Books ', 'Walmart for Business ',
#        'Office Supplies ', 'Video Games ', 'Arts Crafts & Sewing ',
#        'Shop by Movie ', 'Seasonal ', 'Household essentials ',
#        'Party & occasions ', 'Auto & tires ', 'Jewelry ',
#        'Patio & garden ', 'Shop by movie ', 'Music ',
#        'Shop by Video Game ', 'Character Shop ', 'Sports & outdoors ',
#        'Personal care ', 'Premium beauty ', 'Shop by brand ',
#        'Home improvement ', 'Industrial & scientific ',
#        'Arts, Crafts & Sewing ', 'Cell Phones ', 'Musical Instruments ',
# ...

# %%
product_master_data["subCategory"].unique()
# Out:
# array([' Medicine Cabinet ', ' Premium Fragrance ', ' Outdoor Sports ',
#        ' Diapering ', ' Diabetes Care ', ' Feeding ', ' Quit Smoking ',
#        ' Sports ', ' Bikes ', ' Chocolate, Candy & Gum ',
#        ' Home Health Care ', ' Mens Clothing ', ' Exercise & Fitness ',
#        ' Decor ', ' Baby Activities & Gear ', ' Oral Care ',
#        ' Recreation ', 'No Category', ' Kids Bikes & Riding Toys ',
#        ' Foot Care ', ' Probiotics ', ' Sports Fan Shop ', ' Shaving ',
#        ' Dogs ', ' Bath & Body ', ' Car Seats ',
#        ' Automotive Replacement Parts ', ' Nursery & Decor ',
#        ' Weight Management ', ' Shoe Care & Repair ', ' Light Bulbs ',
#        ' Cleaning Supplies ', ' Outdoor Play ', ' Pest Control ',
#        ' Womens Clothing ', ' Premium Hair Care ', ' Strollers ',
#        ' Toddlers Room ', ' Cold Cough and Flu ', ' Hot Tubs & Saunas ',
#        ' Personalized Gifts ', ' Ear Care ', ' Garden Center ',
# ...

# %%
category_mapping = {
    ' Medicine Cabinet ': 'Drama',
    ' Premium Fragrance ': 'Romance',
    ' Outdoor Sports ': 'Action & Adventure',
    ' Diapering ': 'Family & Kids',
    ' Diabetes Care ': 'Drama',
    ' Feeding ': 'Family & Kids',
    ' Quit Smoking ': 'Drama',
    ' Sports ': 'Action & Adventure',
    ' Bikes ': 'Action & Adventure',
    ' Chocolate, Candy & Gum ': 'Comedy',
    ' Home Health Care ': 'Drama',
    ' Mens Clothing ': 'Drama',
    ' Exercise & Fitness ': 'Action & Adventure',
    ' Decor ': 'Thriller & Mystery',
    ' Baby Activities & Gear ': 'Family & Kids',
    ' Oral Care ': 'Drama',
    ' Recreation ': 'Action & Adventure',
    'No Category': 'Other',
    ' Kids Bikes & Riding Toys ': 'Family & Kids',
    ' Foot Care ': 'Drama',
    ' Probiotics ': 'Drama',
    ' Sports Fan Shop ': 'Action & Adventure',
    ' Shaving ': 'Romance',
    ' Dogs ': 'Pets',
    ' Bath & Body ': 'Romance',
    ' Car Seats ': 'Family & Kids',
    ' Automotive Replacement Parts ': 'Action & Adventure',
    ' Nursery & Decor ': 'Thriller & Mystery',
    ' Weight Management ': 'Drama',
    ' Shoe Care & Repair ': 'Drama',
    ' Light Bulbs ': 'Thriller & Mystery',
    ' Cleaning Supplies ': 'Thriller & Mystery',
    ' Outdoor Play ': 'Family & Kids',
    ' Pest Control ': 'Thriller & Mystery',
    ' Womens Clothing ': 'Drama',
    ' Premium Hair Care ': 'Romance',
    ' Strollers ': 'Family & Kids',
    ' Toddlers Room ': 'Family & Kids',
    ' Cold Cough and Flu ': 'Drama',
    ' Hot Tubs & Saunas ': 'Thriller & Mystery',
    ' Personalized Gifts ': 'Other',
    ' Ear Care ': 'Drama',
    ' Garden Center ': 'Thriller & Mystery',
    ' Baby Clearance ': 'Family & Kids',
    ' Breakfast & Cereal ': 'Comedy',
    ' Home Safety ': 'Thriller & Mystery',
    ' Sports & Outdoors ': 'Action & Adventure',
    ' Beverages ': 'Comedy',
    ' Sports Medicine & Injury Recovery Solution ': 'Drama',
    ' Snacks, Cookies & Chips ': 'Comedy',
    ' Protein & Fitness ': 'Drama',
    ' Meal Solutions, Grains & Pasta ': 'Comedy',
    ' Sleep & Snoring Aids ': 'Drama',
    ' Batteries ': 'Fantasy & Sci-Fi',
    ' Condiments, Sauces & Spices ': 'Comedy',
    ' Coffee ': 'Comedy',
    ' Health & Safety ': 'Drama',
    ' Here for Every Beauty ': 'Romance',
    ' Fragrances ': 'Romance',
    ' Laundry ': 'Thriller & Mystery',
    ' Paper & Plastic ': 'Thriller & Mystery',
    ' The 80s Shop ': 'Drama',
    ' Games & Puzzles ': 'Family & Kids',
    ' Mens Essentials ': 'Drama',
    ' Incontinence ': 'Drama',
    ' Exterior Car Accessories ': 'Action & Adventure',
    ' Digestive Health ': 'Drama',
    ' All Departments ': 'Other',
    ' Auto Detailing & Car Care ': 'Action & Adventure',
    ' Patio Furniture ': 'Thriller & Mystery',
    ' Acid Reflux ': 'Drama',
    ' Appliances ': 'Thriller & Mystery',
    ' Baking ': 'Comedy',
    ' Party Supplies ': 'Comedy',
    ' First Aid ': 'Drama',
    ' Baby & Toddler Toys ': 'Family & Kids',
    ' Furniture ': 'Thriller & Mystery',
    ' Fashion Brands ': 'Drama',
    ' Smart Home ': 'Fantasy & Sci-Fi',
    ' Pain Relievers ': 'Drama',
    ' Bath ': 'Thriller & Mystery',
    ' Fresh Cut Flowers ': 'Thriller & Mystery',
    ' Shop Toys by Age ': 'Family & Kids',
    ' Juniors ': 'Drama',
    ' Skin Care ': 'Romance',
    ' Kitchen & Dining ': 'Comedy',
    ' Stuffed Animals & Plush Toys ': 'Family & Kids',
    ' Kids Clothing ': 'Drama',
    ' Feminine Care ': 'Drama',
    ' Christmas Trees & Christmas Decor ': 'Family & Kids',
    ' Emergency Prep ': 'Thriller & Mystery',
    ' Sun Care ': 'Drama',
    ' Organic Foods ': 'Comedy',
    ' Superfoods & Cleanses ': 'Comedy',
    ' Vitamins & Supplements ': 'Drama',
    ' Aromatherapy ': 'Drama',
    ' Home ': 'Thriller & Mystery',
    ' Food Service Equipment & Supplies ': 'Thriller & Mystery',
    ' Beauty by Top Brands ': 'Romance',
    ' Fiber Supplements ': 'Drama',
    ' Eye Care ': 'Drama',
    ' Caregiver ': 'Drama',
    ' Childrens Health ': 'Drama',
    ' Seasonal Grocery ': 'Comedy',
    ' Restock Health Essentials ': 'Drama',
    ' Bathroom ': 'Thriller & Mystery',
    ' Household Essentials ': 'Thriller & Mystery',
    ' Bags & Accessories ': 'Drama',
    ' Diabetes Care Brands ': 'Drama',
    ' Childrens & Kids Books ': 'Documentary',
    ' Heating, Cooling, & Air Quality ': 'Thriller & Mystery',
    ' Kids Rooms ': 'Thriller & Mystery',
    ' Premium Bath & Body ': 'Romance',
    ' Janitorial & Sanitation Supplies ': 'Thriller & Mystery',
    ' Baby Shower Gifts ': 'Family & Kids',
    ' @ Manual Shelves - Sports & Outdoors ': 'Action & Adventure',
    ' Hardware ': 'Action & Adventure',
    ' Grills & Outdoor Cooking ': 'Action & Adventure',
    ' Restock & Save On Hair Care ': 'Romance',
    ' Breakroom Supplies ': 'Thriller & Mystery',
    ' Bathroom Renovation ': 'Thriller & Mystery',
    ' Diabetes Shop ': 'Drama',
    ' Office Supplies & School Supplies by Brand ': 'Documentary',
    ' Clean Living Bath & Body ': 'Romance',
    ' Motorcycle ': 'Action & Adventure',
    ' Fragrance Best Sellers ': 'Romance',
    ' Office Technology ': 'Fantasy & Sci-Fi',
    ' Fresh Food ': 'Comedy',
    ' Shop Toys by Brand ': 'Family & Kids',
    ' Air Fresheners ': 'Thriller & Mystery',
    ' Paint ': 'Thriller & Mystery',
    ' New Arrivals ': 'Other',
    ' Automotive Tools & Equipment ': 'Action & Adventure',
    ' Premium Mens Grooming ': 'Romance',
    ' Diabetes Management ': 'Drama',
    ' Spring Break Beauty ': 'Romance',
    ' Bedding ': 'Thriller & Mystery',
    ' Retro and Arcade Gaming Consoles, Accessories & Games ': 'Fantasy & Sci-Fi',
    ' Crafting ': 'Hobbies & Crafts',
    ' Bedding ': 'Thriller & Mystery',
    ' Household Essentials by Brand ': 'Thriller & Mystery',
    ' Hair Care ': 'Romance',
    ' Unicorn Shop ': 'Family & Kids',
    ' Shoes ': 'Drama',
    ' Tools ': 'Action & Adventure',
    ' Big & Tall ': 'Drama',
    ' Beauty Wellness ': 'Romance',
    ' Toys Character Shop ': 'Family & Kids',
    ' Seasonal Clothing Shops ': 'Drama',
    ' Health & safety ': 'Drama',
    ' Fast & Furious ': 'Family & Kids',
    ' Cats ': 'Pets',
    ' Clean Living Shop ': 'Thriller & Mystery',
    ' Motion Sickness & Nausea ': 'Drama',
    ' Childrens Health Shop ': 'Drama',
    ' Water Purification ': 'Thriller & Mystery',
    ' Paper & plastic ': 'Thriller & Mystery',
    ' Car seats ': 'Family & Kids',
    ' Gas Relief ': 'Drama',
    ' Professional Safety Shop ': 'Drama',
    ' Sexual Wellness Top Brands ': 'Drama',
    ' Premium Hair Care & Hair Tools ': 'Romance',
    ' Premium K-Beauty ': 'Romance',
    ' Laxatives ': 'Drama',
    ' Light bulbs ': 'Thriller & Mystery',
    ' Premium Facial Skincare ': 'Romance',
    ' Cleaning supplies ': 'Thriller & Mystery',
    ' Family Planning ': 'Drama',
    ' Nursery & decor ': 'Thriller & Mystery',
    ' Pest control ': 'Thriller & Mystery',
    ' Baby activities & gear ': 'Family & Kids',
    ' Party supplies ': 'Comedy',
    ' Allergy and Sinus ': 'Drama',
    ' Specialty Shops ': 'Other',
    ' Food & Grocery ': 'Comedy',
    ' Auto detailing & car care ': 'Action & Adventure',
    ' Sexual Wellness ': 'Drama',
    ' Shop by Skin Concern and Type ': 'Romance',
    ' Dolls & Dollhouses ': 'Family & Kids',
    ' Premium Beauty ': 'Romance',
    ' Trending ': 'Other',
    ' Kids clothing ': 'Drama',
    ' Lip Care ': 'Romance',
    ' Smart home ': 'Fantasy & Sci-Fi',
    ' Patio & Outdoor Decor ': 'Thriller & Mystery',
    ' Makeup ': 'Romance',
    ' Premium Makeup ': 'Romance',
    ' Electrical ': 'Fantasy & Sci-Fi',
    ' Kitchen Renovation ': 'Thriller & Mystery',
    ' Watch Accessories ': 'Drama',
    ' Kids rooms ': 'Thriller & Mystery',
    ' Medicine Cabinet Must Haves ': 'Drama',
    ' Baby clearance ': 'Family & Kids',
    ' Stock up essentials ': 'Other',
    ' Valentines Day Beauty Gifts ': 'Romance',
    ' Featured Brands ': 'Other',
    ' Teens Rooms ': 'Thriller & Mystery',
    ' Automotive Interior ': 'Action & Adventure',
    ' Medical & Dental ': 'Drama',
    ' Heart Health ': 'Drama',
    ' Bags & accessories ': 'Drama',
    ' Auto Detailing Paint and Paint Tools ': 'Action & Adventure',
    ' Baby & toddler toys ': 'Family & Kids',
    ' Watches ': 'Drama',
    ' New Year New You ': 'Other',
    ' Garden center ': 'Thriller & Mystery',
    ' Storage & Organization ': 'Thriller & Mystery',
    ' Jumanji ': 'Family & Kids',
    ' Premium Tools & Brushes ': 'Action & Adventure',
    ' Stock Up Essentials ': 'Other',
    ' Toddlers room ': 'Family & Kids',
    ' Premium Hair Tools & Accessories ': 'Romance',
    ' Cake, Baking & Pastry Supplies ': 'Comedy',
    ' Small Animals ': 'Pets',
    ' Psychology & Social Science Books ': 'Documentary',
    ' Premium Brands ': 'Other',
    ' Massage ': 'Romance',
    ' Rock Music on CD or Vinyl ': 'Music',
    ' Hairitage ': 'Romance',
    ' As Seen on TV ': 'Fantasy & Sci-Fi',
    ' Equate ': 'Drama',
    ' Sewing ': 'Hobbies & Crafts',
    ' Registry ': 'Other',
    ' @ Manual Shelves - Food ': 'Comedy',
    ' Birds ': 'Pets',
    ' Premium Party Shop ': 'Comedy',
    ' Keto Diet ': 'Comedy',
    ' Remote Control & Play Vehicles ': 'Family & Kids',
    ' Premium Beauty Tech & Skin Devices ': 'Romance',
    ' Horses ': 'Pets',
    ' Super Mario ': 'Family & Kids',
    ' Cameras & Camcorders ': 'Fantasy & Sci-Fi',
    ' Occupational Health & Safety Products ': 'Drama',
    ' Travel Size Beauty ': 'Romance',
    ' Nickelodeon Characters ': 'Family & Kids',
    ' Jojo Siwa Party Supplies ': 'Comedy',
    ' Pretend Play ': 'Family & Kids',
    ' Computers ': 'Fantasy & Sci-Fi',
    ' Gift Baskets ': 'Other',
    ' Halloween ': 'Holiday',
    ' Learning Toys ': 'Family & Kids',
    ' STEM ': 'Family & Kids',
    ' Hot Tubs ': 'Thriller & Mystery',
    ' Character Shop ': 'Family & Kids',
    ' Country Music on CD or Vinyl ': 'Music',
    ' Desk & Workspace Organizers ': 'Documentary',
    ' Philosophy Books ': 'Documentary',
    ' Oils and Fluids Home ': 'Action & Adventure',
    ' Outdoor Power Equipment ': 'Thriller & Mystery',
    ' The Curl Shop ': 'Romance',
    ' Plant Based Nutrition ': 'Comedy',
    ' Building Materials ': 'Thriller & Mystery',
    ' Kosher Foods ': 'Comedy',
    ' Mothers Day ': 'Holiday',
    ' Business & Money Books':'Drama',
    ' Plant Based Nutrition ': 'Comedy',
    ' Building Materials ': 'Thriller & Mystery',
    ' Kosher Foods ': 'Comedy',
    ' Mothers Day ': 'Holiday',
    ' Business & Money Books ': 'Documentary',
    ' Tires ': 'Action & Adventure',
    ' ATV & Off-Road ': 'Action & Adventure',
    ' Arts & Crafts for Kids ': 'Family & Kids',
    ' Sleepwear Shop ': 'Drama',
    ' Paper ': 'Thriller & Mystery',
    ' Fathers Day Books ': 'Holiday',
    ' Rulers, Compasses & Protractors ': 'Thriller & Mystery',
    ' Telescopes and Microscopes ': 'Documentary',
    ' Outdoor sports ': 'Action & Adventure',
    ' Mens essentials ': 'Drama',
    ' Bath & body ': 'Romance',
    ' Sexual wellness ': 'Drama',
    ' Restock & save on hair care ': 'Romance',
    ' Hobby & Collectible Toys ': 'Family & Kids',
    ' Feminine care ': 'Drama',
    ' Premium bath & body ': 'Romance',
    ' Savings ': 'Other',
    ' Oral care ': 'Romance',
    ' All departments ': 'Other',
    ' Here for every beauty ': 'Romance',
    ' Arts & Entertainment Books ': 'Documentary',
    ' Hair care ': 'Romance',
    ' New arrivals ': 'Other',
    ' Women ': 'Drama',
    ' Shoe care & repair ': 'Action & Adventure',
    ' Advance Auto Parts Shop ': 'Action & Adventure',
    ' Oils and Fluids ': 'Action & Adventure',
    ' Janitorial & sanitation supplies ': 'Thriller & Mystery',
    ' Premium mens grooming ': 'Romance',
    ' Health Holiday Gifts ': 'Drama',
    ' Maternity Clothing ': 'Family & Kids',
    ' Language Arts & Disciplines Books ': 'Documentary',
    ' Sports & Outdoor Books ': 'Action & Adventure',
    ' Kitchen & dining ': 'Comedy',
    ' Disney Toys ': 'Family & Kids',
    ' Vision Centers ': 'Drama',
    ' Mens clothing ': 'Drama',
    ' Self-Care & Pampering ': 'Romance',
    ' Sexual wellness top brands ': 'Drama',
    ' The curl shop ': 'Romance',
    ' Sun care ': 'Drama',
    ' Premium fragrance ': 'Romance',
    ' Outdoor Lighting ': 'Thriller & Mystery',
    ' Beading & Jewelry Making ': 'Family & Kids',
    ' Boys Clothing ': 'Family & Kids',
    ' Farm & Ranch ': 'Action & Adventure',
    ' Shop by Brand ': 'Other',
    ' Premium hair care ': 'Romance',
    ' Premium facial skincare ': 'Romance',
    ' Home Improvement ': 'Thriller & Mystery',
    ' Premium hair care & hair tools ': 'Romance',
    ' Cellphone Accessories ': 'Fantasy & Sci-Fi',
    ' Wellness ': 'Drama',
    ' Womens Plus ': 'Drama',
    ' Sports Party Supplies ': 'Comedy',
    ' Unicorn Party Supplies ': 'Comedy',
    ' Building materials ': 'Thriller & Mystery',
    ' Portable Audio ': 'Fantasy & Sci-Fi',
    ' Meal solutions, grains & pasta ': 'Comedy',
    ' Chocolate, candy & gum ': 'Comedy',
    ' Outdoor play ': 'Family & Kids',
    ' Snacks, cookies & chips ': 'Comedy',
    ' Fresh cut flowers ': 'Thriller & Mystery',
    ' WWE ': 'Action & Adventure',
    ' Condiments, sauces & spices ': 'Comedy',
    ' Tape ': 'Thriller & Mystery',
    ' Fresh food ': 'Comedy',
    ' Pajama Shop ': 'Drama',
    ' Air fresheners ': 'Thriller & Mystery',
    ' Vitamins & supplements ': 'Drama',
    ' Dog & Cat Nutrition Shop ': 'Pets',
    ' Games & puzzles ': 'Family & Kids',
    ' Frozen ': 'Family & Kids',
    ' Party Supplies by Brand ': 'Comedy',
    ' Candy & Gum ': 'Comedy',
    ' Swim Shop ': 'Family & Kids',
    ' House, Home & Gardening Books ': 'Documentary',
    ' Literature & Fiction Books ': 'Documentary',
    ' Presentation Boards & Presentation Easels ': 'Thriller & Mystery',
    ' Scissors ': 'Thriller & Mystery',
    ' Personal Care by Brand ': 'Romance',
    ' Art Supplies ': 'Family & Kids',
    ' Beauty by topic ': 'Romance',
    ' Sleep Solutions ': 'Drama',
    ' Wilton Baking Supplies ': 'Comedy',
    ' Sports fan shop ': 'Action & Adventure',
    ' Birthday Shop ': 'Comedy',
    ' Instrument Accessories ': 'Music',
    ' Preschool Toys ': 'Family & Kids',
    ' History Books ': 'Documentary',
    ' Back to School ': 'Family & Kids',
    ' Dermatologist Recommended ': 'Romance',
    ' Disney Characters ': 'Family & Kids',
    'NetworkingDevices': 'Fantasy & Sci-Fi',
    'HomeTheater,TV&Video': 'Fantasy & Sci-Fi',
    'Accessories&Peripherals': 'Fantasy & Sci-Fi',
    'HomeAudio': 'Fantasy & Sci-Fi',
    'WearableTechnology': 'Fantasy & Sci-Fi',
    'Mobiles&Accessories': 'Fantasy & Sci-Fi',
    'Headphones,Earbuds&Accessories': 'Fantasy & Sci-Fi',
    'Accessories': 'Fantasy & Sci-Fi',
    'ExternalDevices&DataStorage': 'Fantasy & Sci-Fi',
    'Microphones': 'Fantasy & Sci-Fi',
    'GeneralPurposeBatteries&BatteryChargers': 'Fantasy & Sci-Fi',
    'OfficePaperProducts': 'Documentary',
    'CraftMaterials': 'Family & Kids',
    'Cameras&Photography': 'Family & Kids',
    'OfficeElectronics': 'Documentary',
    'Printers,Inks&Accessories': 'Fantasy & Sci-Fi',
    'Components': 'Fantasy & Sci-Fi',
    'Electrical': 'Fantasy & Sci-Fi',
    'Arts&Crafts': 'Family & Kids',
    'PowerAccessories': 'Fantasy & Sci-Fi',
    'Laptops': 'Fantasy & Sci',
    'Electrical': 'Fantasy & Sci-Fi',
    'Arts&Crafts': 'Music & Arts',
    'PowerAccessories': 'Fantasy & Sci-Fi',
    'Laptops': 'Fantasy & Sci-Fi',
    'Kitchen&HomeAppliances': 'Comedy',
    'Heating,Cooling&AirQuality': 'Thriller & Mystery',
    'Kitchen&Dining': 'Comedy',
    'HomeStorage&Organization': 'Thriller & Mystery',
    'CarAccessories': 'Action & Adventure',
    'HomeMedicalSupplies&Equipment': 'Drama'
}

# %%
# Apply the updated genre mapping to create the 'Genres' column
product_master_data["movie_generes"]=product_master_data["subCategory"].map(category_mapping)

# # Display the updated fashion dataset with the 'Genres' column
product_master_data
# Out:
#        product_id                                       product_name  \
# 0      0132793040  Allegiance Economy Dual-scale Digital Thermometer
# 1      0321732944  Kenneth Cole Reaction Eau De Parfum Spray For ...
# 2      0439886341  Kid Tough Fitness Inflatable Free-Standing Pun...
# 3      0511189877                                    THE FIRST YEARS
# 4      0528881469  4 Pack - MD USA Seamless Toe-Wave-In Mesh Diab...
# ...           ...                                                ...
# 31254  B0002V8N06  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 31255  B0002V9G6G  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 31256  B0002V9IJG  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 31257  B0002V9IK0  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 31258  B0002V9IKA  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#       actual_price  discounted_price            Brand      masterCategory  \
# ...

# %%
product_master_data[product_master_data['movie_generes']=="Thriller & Mystery"]
# Out:
#        product_id                                       product_name  \
# 28     0594549558  Artistic Weavers Trudy Vivienne 18" x 18" Pill...
# 65     1400698987  TSV Motion Sensor LED Lamp Holder Switch, E26/...
# 70     1444501399  Bacati - Dots/Pin Stripes Hamper with Cotton P...
# 77     1604550945  Luxrite LR20730 (10-Pack) F32T8/841 32-Watt 4 ...
# 80     1615527613    Weber 8 Oz. Grill Exterior Barbeque Cleaner W66
# ...           ...                                                ...
# 31247  B0002V85MM               Usha Hc 812 T Thermo Fan Room Heater
# 31249  B0002V85OU  USHA 1212 PTC with Adjustable Thermostat Fan H...
# 31252  B0002V8KZE  Libra Room Heater for Home, Room Heaters Home ...
# 31256  B0002V9IJG  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 31257  B0002V9IK0  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
#
#       actual_price  discounted_price             Brand         masterCategory  \
# ...

# %% [markdown]
# #### Handling Nuances in Fashion data
#
# - We found out some of the columns in fashion data contains NaN values so In this segment we handle those problems

# %%
fashion_data
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44419  17036    Men       Footwear       Shoes           Casual Shoes
# 44420   6461    Men       Footwear  Flip Flops             Flip Flops
# 44421  18842    Men        Apparel     Topwear                Tshirts
# 44422  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44423  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
fashion_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44424 entries, 0 to 44423
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44424 non-null  int64
#  1   gender              44424 non-null  object
#  2   masterCategory      44424 non-null  object
#  3   subCategory         44424 non-null  object
#  4   articleType         44424 non-null  object
#  5   baseColour          44409 non-null  object
#  6   season              44403 non-null  object
#  7   year                44423 non-null  float64
#  8   usage               44107 non-null  object
#  9   productDisplayName  44417 non-null  object
#  10  movie_generes       44424 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 3.7+ MB

# %%
fashion_data.isna().sum()
# Out:
# id                      0
# gender                  0
# masterCategory          0
# subCategory             0
# articleType             0
# baseColour             15
# season                 21
# year                    1
# usage                 317
# productDisplayName      7
# movie_generes           0
# dtype: int64

# %%
fashion_data[fashion_data["usage"].isna()==True]
# Out:
#           id  gender masterCategory       subCategory            articleType  \
# 87     56489   Women  Personal Care             Nails            Nail Polish
# 92     52029  Unisex        Apparel           Topwear            Rain Jacket
# 292    55001   Women  Personal Care              Lips               Lipstick
# 479    57563   Women  Personal Care              Lips               Lipstick
# 511    55006   Women  Personal Care              Lips              Lip Gloss
# ...      ...     ...            ...               ...                    ...
# 43633  56605   Women  Personal Care            Makeup     Kajal and Eyeliner
# 44079  57715   Women  Personal Care              Lips              Lip Gloss
# 44224  43120     Men  Personal Care         Fragrance  Perfume and Body Mist
# 44227  55045   Women  Personal Care              Lips               Lipstick
# 44343   6839  Unisex    Accessories  Shoe Accessories       Shoe Accessories
#
#          baseColour  season    year usage  \
# ...

# %%
fashion_data[fashion_data["usage"]=="Smart Casual"]
# Out:
#           id gender masterCategory subCategory   articleType baseColour  \
# 1104   27870  Women        Apparel     Topwear        Shirts      White
# 4263   11324    Men        Apparel  Bottomwear      Trousers      Black
# 5860   20715    Men       Footwear       Shoes  Casual Shoes      Black
# 6440   59986  Women        Apparel       Dress       Dresses      Black
# 6486   46536    Men    Accessories     Watches       Watches      Black
# ...      ...    ...            ...         ...           ...        ...
# 41732  27869  Women        Apparel     Topwear        Shirts      White
# 41912  59287  Women    Accessories     Watches       Watches       Gold
# 42093  33694    Men       Footwear       Shoes  Formal Shoes      Brown
# 43790  58796    Men        Apparel     Topwear        Shirts  Navy Blue
# 43853  57518    Men       Footwear       Shoes  Casual Shoes        Tan
#
#        season    year         usage  \
# 1104     Fall  2012.0  Smart Casual
# ...

# %%
fashion_data["usage"]=fashion_data["usage"].fillna("Smart Casual")

# %%
fashion_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44424 entries, 0 to 44423
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44424 non-null  int64
#  1   gender              44424 non-null  object
#  2   masterCategory      44424 non-null  object
#  3   subCategory         44424 non-null  object
#  4   articleType         44424 non-null  object
#  5   baseColour          44409 non-null  object
#  6   season              44403 non-null  object
#  7   year                44423 non-null  float64
#  8   usage               44424 non-null  object
#  9   productDisplayName  44417 non-null  object
#  10  movie_generes       44424 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 3.7+ MB

# %%
fashion_data.isna().sum()
# Out:
# id                     0
# gender                 0
# masterCategory         0
# subCategory            0
# articleType            0
# baseColour            15
# season                21
# year                   1
# usage                  0
# productDisplayName     7
# movie_generes          0
# dtype: int64

# %%
fashion_data[fashion_data["season"].isna()==True]
# Out:
#           id  gender masterCategory subCategory   articleType baseColour  \
# 282     5402   Women       Footwear       Shoes  Sports Shoes     Purple
# 5997    5389  Unisex       Footwear       Shoes  Sports Shoes     Yellow
# 6510    5380   Women       Footwear       Shoes  Sports Shoes     Purple
# 12658   5392  Unisex       Footwear       Shoes  Sports Shoes      White
# 12994   5361     Men       Footwear       Shoes  Sports Shoes      Black
# 13523   5368     Men       Footwear       Shoes  Sports Shoes        Red
# 16042   5360   Women       Footwear       Shoes  Sports Shoes       Grey
# 21272  53781     Men        Apparel     Topwear       Tshirts       Blue
# 23835   5406   Women       Footwear       Shoes  Sports Shoes       Blue
# 24198   5401   Women       Footwear       Shoes  Sports Shoes       Blue
# 27725   5407   Women       Footwear       Shoes  Sports Shoes      Beige
# 30113   5370     Men       Footwear       Shoes  Sports Shoes      Black
# ...

# %%
fashion_data["season"]=fashion_data["season"].fillna(np.random.choice(["Summer","Fall"]))

# %%
fashion_data["baseColour"]=fashion_data["baseColour"].fillna(fashion_data["baseColour"].mode()[0])

# %%
fashion_data.isna().sum()
# Out:
# id                    0
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# year                  1
# usage                 0
# productDisplayName    7
# movie_generes         0
# dtype: int64

# %%
fashion_data[fashion_data["productDisplayName"].isna()==True]
# Out:
#           id gender masterCategory subCategory            articleType  \
# 3677   42878  Women    Accessories        Bags               Clutches
# 14291  30991  Women  Personal Care   Fragrance  Perfume and Body Mist
# 17639  45687    Men  Personal Care   Fragrance  Perfume and Body Mist
# 22089  42863  Women    Accessories        Bags               Clutches
# 23484  45698  Women  Personal Care   Fragrance  Perfume and Body Mist
# 37531  30992    Men  Personal Care   Fragrance  Perfume and Body Mist
# 40675  43119    Men  Personal Care   Fragrance  Perfume and Body Mist
#
#       baseColour  season    year         usage productDisplayName  \
# 3677      Maroon  Summer  2012.0        Casual                NaN
# 14291      Black  Spring  2017.0  Smart Casual                NaN
# 17639      Black  Spring  2017.0  Smart Casual                NaN
# 22089      Brown  Summer  2012.0        Casual                NaN
# 23484      Black  Spring  2017.0  Smart Casual                NaN
# ...

# %%
product_name_mode=fashion_data[(fashion_data["subCategory"]=="Fragrance") & (fashion_data["articleType"]=="Perfume and Body Mist")]["productDisplayName"].mode()

# %%
fashion_data["productDisplayName"]=fashion_data["productDisplayName"].fillna(product_name_mode[0])

# %%
fashion_data.isna().sum()
# Out:
# id                    0
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# year                  1
# usage                 0
# productDisplayName    0
# movie_generes         0
# dtype: int64

# %%
fashion_data["year"]=fashion_data["year"].fillna(fashion_data["year"].mode()[0]).astype("int32")

# %%
fashion_data.isna().sum()
# Out:
# id                    0
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# year                  0
# usage                 0
# productDisplayName    0
# movie_generes         0
# dtype: int64

# %% [markdown]
# **The Fashion data looks clean and Neat, so I'm moving further to do major operations**

# %%
fashion_data
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44419  17036    Men       Footwear       Shoes           Casual Shoes
# 44420   6461    Men       Footwear  Flip Flops             Flip Flops
# 44421  18842    Men        Apparel     Topwear                Tshirts
# 44422  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44423  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season  year   usage  \
# 0      Navy Blue    Fall  2011  Casual
# 1           Blue  Summer  2012  Casual
# ...

# %% [markdown]
# #### Assign product ID for the fashion data

# %%
fashion_data['productDisplayName'].unique()
# Out:
# array(['Turtle Check Men Navy Blue Shirt',
#        'Peter England Men Party Blue Jeans', 'Titan Women Silver Watch',
#        ..., "Lotto Men's Soccer Track Flip Flop",
#        'Puma Men Graphic Stellar Blue Tshirt',
#        'Fossil Women Pink Dial Chronograph Watch ES3050'], dtype=object)

# %%
non_duplicate_data=fashion_data.drop_duplicates(subset=['productDisplayName'], keep=False,ignore_index=True)

# %%
non_duplicate_data
# Out:
#           id gender masterCategory subCategory   articleType baseColour  \
# 0      15970    Men        Apparel     Topwear        Shirts  Navy Blue
# 1      39386    Men        Apparel  Bottomwear         Jeans       Blue
# 2      21379    Men        Apparel  Bottomwear   Track Pants      Black
# 3       1855    Men        Apparel     Topwear       Tshirts       Grey
# 4      30805    Men        Apparel     Topwear        Shirts      Green
# ...      ...    ...            ...         ...           ...        ...
# 26017  12544  Women        Apparel     Topwear       Tshirts      Peach
# 26018  17036    Men       Footwear       Shoes  Casual Shoes      White
# 26019   6461    Men       Footwear  Flip Flops    Flip Flops        Red
# 26020  18842    Men        Apparel     Topwear       Tshirts       Blue
# 26021  51623  Women    Accessories     Watches       Watches       Pink
#
#        season  year   usage                               productDisplayName  \
# ...

# %% [markdown]
# **Get the data's length for set the product Id**

# %%
fashion_product_id=unique_dataset["product_id"][len(product_master_data):len(product_master_data)+len(non_duplicate_data)]
fashion_product_id
# Out:
# 31259    B0002V9IKK
# 31260    B0002V9INM
# 31261    B0002VAFYS
# 31262    B0002VAHZA
# 31263    B0002VAI04
#             ...
# 57276    B000GC9210
# 57277    B000GC98H8
# 57278    B000GC98IM
# 57279    B000GC98IW
# 57280    B000GC9AX0
# Name: product_id, Length: 26022, dtype: object

# %% [markdown]
# **Creating dataframe with product Id for merge and make master product dataset**

# %%
fashion_id=pd.DataFrame({"product_id":fashion_product_id})
fashion_id.reset_index(inplace=True)
fashion_id.drop(columns="index",inplace=True)

#Join it with fashion dataset
fashion_data=pd.concat([fashion_id,non_duplicate_data],axis=1)
fashion_data
# Out:
#        product_id     id gender masterCategory subCategory   articleType  \
# 0      B0002V9IKK  15970    Men        Apparel     Topwear        Shirts
# 1      B0002V9INM  39386    Men        Apparel  Bottomwear         Jeans
# 2      B0002VAFYS  21379    Men        Apparel  Bottomwear   Track Pants
# 3      B0002VAHZA   1855    Men        Apparel     Topwear       Tshirts
# 4      B0002VAI04  30805    Men        Apparel     Topwear        Shirts
# ...           ...    ...    ...            ...         ...           ...
# 26017  B000GC9210  12544  Women        Apparel     Topwear       Tshirts
# 26018  B000GC98H8  17036    Men       Footwear       Shoes  Casual Shoes
# 26019  B000GC98IM   6461    Men       Footwear  Flip Flops    Flip Flops
# 26020  B000GC98IW  18842    Men        Apparel     Topwear       Tshirts
# 26021  B000GC9AX0  51623  Women    Accessories     Watches       Watches
#
#       baseColour  season  year   usage  \
# 0      Navy Blue    Fall  2011  Casual
# ...

# %% [markdown]
# ### Create Master Data
#
# **In this crucial step I'm gonna create Master Data with fashion and Product Id Information and I'm gonna use this as for my further model training**

# %%
# ##Create one dataframe in stacking format
# product_id_df=pd.concat([amazon_id,fashion_id])
# product_id_df.reset_index(inplace=True)
# product_id_df.drop(columns="index",inplace=True)
# product_id_df

fashion_id_generes=fashion_data[['product_id','movie_generes']]
# electronics_product_id=product_master_data[["product_id","movie_generes"]]
# product_id_df=pd.concat([fashion_id_generes,electronics_product_id])
# product_id_df
fashion_id_generes
# Out:
#        product_id       movie_generes
# 0      B0002V9IKK               Drama
# 1      B0002V9INM               Drama
# 2      B0002VAFYS   Sports & Outdoors
# 3      B0002VAHZA              Comedy
# 4      B0002VAI04               Drama
# ...           ...                 ...
# 26017  B000GC9210              Comedy
# 26018  B000GC98H8               Drama
# 26019  B000GC98IM       Family & Kids
# 26020  B000GC98IW              Comedy
# 26021  B000GC9AX0  Action & Adventure
#
# [26022 rows x 2 columns]

# %%
product_id_df=product_master_data[["product_id","movie_generes"]]

# %%
product_master_data
# Out:
#        product_id                                       product_name  \
# 0      0132793040  Allegiance Economy Dual-scale Digital Thermometer
# 1      0321732944  Kenneth Cole Reaction Eau De Parfum Spray For ...
# 2      0439886341  Kid Tough Fitness Inflatable Free-Standing Pun...
# 3      0511189877                                    THE FIRST YEARS
# 4      0528881469  4 Pack - MD USA Seamless Toe-Wave-In Mesh Diab...
# ...           ...                                                ...
# 31254  B0002V8N06  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 31255  B0002V9G6G  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 31256  B0002V9IJG  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 31257  B0002V9IK0  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 31258  B0002V9IKA  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#       actual_price  discounted_price            Brand      masterCategory  \
# ...

# %%
# Shuffle the product IDs randomly
product_ids_shuffled = np.random.permutation(product_id_df['product_id'].values)
electronics_ratings['product_id']=np.random.choice(product_ids_shuffled, size=len(electronics_ratings))
electronics_ratings
# Out:
#                 user_id  product_id  rating
# 0         AKM1MP6P0OYPR  B00005OMZT     5.0
# 1        A2CX7LUOHB2NDG  B0001J3PDO     5.0
# 2        A2NWSAGRHCP8N5  B00009KP3I     1.0
# 3        A2WNBOD3WNDNKT  B00004TH9L     3.0
# 4        A1GI0U4ZRJA8WN  B00006LHLW     1.0
# ...                 ...         ...     ...
# 7824477  A2YZI3C9MOHC0L  B0000D93PK     5.0
# 7824478  A322MDK0M89RHN  B00006LEIW     5.0
# 7824479  A1MH90R0ADMIK0  B00002EQCD     4.0
# 7824480  A10M2KEFPEQDHN  B000062YJY     4.0
# 7824481  A2G81TMIOIDEQQ  B0002T5SU6     5.0
#
# [7824482 rows x 3 columns]

# %%
len(product_id_df["product_id"].unique())
# Out:
# 31259

# %%
merged_genere_data=pd.merge(left=electronics_ratings,right=product_id_df,on="product_id")

# electronics_ratings.to_csv("/content/drive/MyDrive/Movie-Product-Recommendation /Datasets/aws_data_merge/product_rating.csv")
# product_id_df.to_csv("/content/drive/MyDrive/Movie-Product-Recommendation /Datasets/aws_data_merge/product_generes.csv")

# %%
merged_genere_data
# Out:
#                 user_id  product_id  rating       movie_generes
# 0         AKM1MP6P0OYPR  B00005OMZT     5.0             Romance
# 1        A261321MIS0YPB  B00005OMZT     4.0             Romance
# 2        A1Z61TUQFZYVFQ  B00005OMZT     4.0             Romance
# 3         AOXT1R95GXUKS  B00005OMZT     5.0             Romance
# 4        A2YSF7XUAQWW36  B00005OMZT     5.0             Romance
# ...                 ...         ...     ...                 ...
# 7824477  A1AN5C5A9I7CJ4  B00008BLGE     5.0  Action & Adventure
# 7824478   AKGB10L3LSVBY  B00008BLGE     5.0  Action & Adventure
# 7824479  A3IW67NCH63W2H  B00008BLGE     5.0  Action & Adventure
# 7824480  A1UYXMHUEWSUZI  B00008BLGE     5.0  Action & Adventure
# 7824481   AK0W2NQFM0OUT  B00008BLGE     5.0  Action & Adventure
#
# [7824482 rows x 4 columns]

# %%
merged_genere_data['rating'].unique()
# Out:
# array([5., 4., 3., 1., 2.])

# %%
len_data=len(merged_genere_data)
random_values = np.random.uniform(0,5, size=len_data)
rounded_values = np.round(random_values * 2) / 2  # Round to the nearest 0.5
merged_genere_data["rating"]=rounded_values

# %%
merged_genere_data["rating"].unique()
# Out:
# array([1. , 0.5, 5. , 3.5, 4.5, 4. , 2.5, 0. , 1.5, 3. , 2. ])

# %%
merged_genere_data.to_csv("/content/drive/MyDrive/Movie-Product-Recommendation /Datasets/Cleaned Data/merged_genere_data.csv")
